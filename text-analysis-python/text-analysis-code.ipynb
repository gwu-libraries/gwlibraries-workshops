# %%
import nltk
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# load data
filename = 'text.txt'
file = open(filename, 'rt')
text = file.read()
file.close()

# %%
# load data
filename = 'text.txt'
file = open(filename, 'rt')
text = file.read()
file.close()
# split into sentences
from nltk import sent_tokenize
sentences = sent_tokenize(text)
print(sentences[0])
# Out:
# The central character in the series is Harry Potter, a boy who lives in the fictional town of Little Whinging, Surrey with his aunt, uncle, and cousin – the Dursleys – and discovers at the age of eleven that he is a wizard, though he lives in the ordinary world of non-magical people known as Muggles.

# %%
from nltk.tokenize import word_tokenize
tokens = word_tokenize(text)
print(len(tokens))
print(tokens[:374])
# Out:
# 429
# ['The', 'central', 'character', 'in', 'the', 'series', 'is', 'Harry', 'Potter', ',', 'a', 'boy', 'who', 'lives', 'in', 'the', 'fictional', 'town', 'of', 'Little', 'Whinging', ',', 'Surrey', 'with', 'his', 'aunt', ',', 'uncle', ',', 'and', 'cousin', '–', 'the', 'Dursleys', '–', 'and', 'discovers', 'at', 'the', 'age', 'of', 'eleven', 'that', 'he', 'is', 'a', 'wizard', ',', 'though', 'he', 'lives', 'in', 'the', 'ordinary', 'world', 'of', 'non-magical', 'people', 'known', 'as', 'Muggles', '.', 'The', 'wizarding', 'world', 'exists', 'parallel', 'to', 'the', 'Muggle', 'world', ',', 'albeit', 'hidden', 'and', 'in', 'secrecy', '.', 'His', 'magical', 'ability', 'is', 'inborn', ',', 'and', 'children', 'with', 'such', 'abilities', 'are', 'invited', 'to', 'attend', 'exclusive', 'magic', 'schools', 'that', 'teach', 'the', 'necessary', 'skills', 'to', 'succeed', 'in', 'the', 'wizarding', 'world', '.', 'Harry', 'becomes', 'a', 'student', 'at', 'Hogwarts', 'School', 'of', 'Witchcraft', 'and', 'Wizardry', ',', 'a', 'wizarding', 'academy', 'in', 'Scotland', ',', 'and', 'it', 'is', 'here', 'where', 'most', 'of', 'the', 'events', 'in', 'the', 'series', 'take', 'place', '.', 'As', 'Harry', 'develops', 'through', 'his', 'adolescence', ',', 'he', 'learns', 'to', 'overcome', 'the', 'problems', 'that', 'face', 'him', ':', 'magical', ',', 'social', ',', 'and', 'emotional', ',', 'including', 'ordinary', 'teenage', 'challenges', 'such', 'as', 'friendships', ',', 'infatuation', ',', 'romantic', 'relationships', ',', 'schoolwork', 'and', 'exams', ',', 'anxiety', ',', 'depression', ',', 'stress', ',', 'and', 'the', 'greater', 'test', 'of', 'preparing', 'himself', 'for', 'the', 'confrontation', 'that', 'lies', 'ahead', 'in', 'wizarding', 'Britain', "'s", 'increasingly-violent', 'second', 'wizarding', 'war', '.', 'Each', 'novel', 'chronicles', 'one', 'year', 'in', 'Harry', "'s", 'life', 'during', 'the', 'period', 'from', '1991', 'to', '1998', '.', 'The', 'books', 'also', 'contain', 'many', 'flashbacks', ',', 'which', 'are', 'frequently', 'experienced', 'by', 'Harry', 'viewing', 'the', 'memories', 'of', 'other', 'characters', 'in', 'a', 'device', 'called', 'a', 'Pensieve', '.', 'The', 'environment', 'Rowling', 'created', 'is', 'intimately', 'connected', 'to', 'reality', '.', 'The', 'British', 'magical', 'community', 'of', 'the', 'Harry', 'Potter', 'books', 'is', 'inspired', 'by', '1990s', 'British', 'culture', ',', 'European', 'folklore', ',', 'classical', 'mythology', 'and', 'alchemy', ',', 'incorporating', 'objects', 'and', 'wildlife', 'such', 'as', 'magic', 'wands', ',', 'magic', 'plants', ',', 'potions', ',', 'spells', ',', 'flying', 'broomsticks', ',', 'centaurs', 'and', 'other', 'magical', 'creatures', ',', 'and', 'the', 'Philosopher', "'s", 'Stone', ',', 'beside', 'others', 'invented', 'by', 'Rowling', '.', 'While', 'the', 'fantasy', 'land', 'of', 'Narnia', 'is', 'an', 'alternate', 'universe', 'and', 'the', 'Lord', 'of', 'the', 'Rings', "'", 'Middle-earth', 'a', 'mythic', 'past', ',', 'the', 'wizarding', 'world', 'of', 'Harry', 'Potter', 'exists', 'parallel', 'to', 'the', 'real', 'world', 'and', 'contains', 'magical', 'versions', 'of', 'the', 'ordinary', 'elements', 'of', 'everyday', 'life', ',', 'with', 'the', 'action', 'mostly']

# %%
# convert to lower case
tokens = [w.lower() for w in tokens]
print(tokens)
# Out:
# ['the', 'central', 'character', 'in', 'the', 'series', 'is', 'harry', 'potter', ',', 'a', 'boy', 'who', 'lives', 'in', 'the', 'fictional', 'town', 'of', 'little', 'whinging', ',', 'surrey', 'with', 'his', 'aunt', ',', 'uncle', ',', 'and', 'cousin', '–', 'the', 'dursleys', '–', 'and', 'discovers', 'at', 'the', 'age', 'of', 'eleven', 'that', 'he', 'is', 'a', 'wizard', ',', 'though', 'he', 'lives', 'in', 'the', 'ordinary', 'world', 'of', 'non-magical', 'people', 'known', 'as', 'muggles', '.', 'the', 'wizarding', 'world', 'exists', 'parallel', 'to', 'the', 'muggle', 'world', ',', 'albeit', 'hidden', 'and', 'in', 'secrecy', '.', 'his', 'magical', 'ability', 'is', 'inborn', ',', 'and', 'children', 'with', 'such', 'abilities', 'are', 'invited', 'to', 'attend', 'exclusive', 'magic', 'schools', 'that', 'teach', 'the', 'necessary', 'skills', 'to', 'succeed', 'in', 'the', 'wizarding', 'world', '.', 'harry', 'becomes', 'a', 'student', 'at', 'hogwarts', 'school', 'of', 'witchcraft', 'and', 'wizardry', ',', 'a', 'wizarding', 'academy', 'in', 'scotland', ',', 'and', 'it', 'is', 'here', 'where', 'most', 'of', 'the', 'events', 'in', 'the', 'series', 'take', 'place', '.', 'as', 'harry', 'develops', 'through', 'his', 'adolescence', ',', 'he', 'learns', 'to', 'overcome', 'the', 'problems', 'that', 'face', 'him', ':', 'magical', ',', 'social', ',', 'and', 'emotional', ',', 'including', 'ordinary', 'teenage', 'challenges', 'such', 'as', 'friendships', ',', 'infatuation', ',', 'romantic', 'relationships', ',', 'schoolwork', 'and', 'exams', ',', 'anxiety', ',', 'depression', ',', 'stress', ',', 'and', 'the', 'greater', 'test', 'of', 'preparing', 'himself', 'for', 'the', 'confrontation', 'that', 'lies', 'ahead', 'in', 'wizarding', 'britain', "'s", 'increasingly-violent', 'second', 'wizarding', 'war', '.', 'each', 'novel', 'chronicles', 'one', 'year', 'in', 'harry', "'s", 'life', 'during', 'the', 'period', 'from', '1991', 'to', '1998', '.', 'the', 'books', 'also', 'contain', 'many', 'flashbacks', ',', 'which', 'are', 'frequently', 'experienced', 'by', 'harry', 'viewing', 'the', 'memories', 'of', 'other', 'characters', 'in', 'a', 'device', 'called', 'a', 'pensieve', '.', 'the', 'environment', 'rowling', 'created', 'is', 'intimately', 'connected', 'to', 'reality', '.', 'the', 'british', 'magical', 'community', 'of', 'the', 'harry', 'potter', 'books', 'is', 'inspired', 'by', '1990s', 'british', 'culture', ',', 'european', 'folklore', ',', 'classical', 'mythology', 'and', 'alchemy', ',', 'incorporating', 'objects', 'and', 'wildlife', 'such', 'as', 'magic', 'wands', ',', 'magic', 'plants', ',', 'potions', ',', 'spells', ',', 'flying', 'broomsticks', ',', 'centaurs', 'and', 'other', 'magical', 'creatures', ',', 'and', 'the', 'philosopher', "'s", 'stone', ',', 'beside', 'others', 'invented', 'by', 'rowling', '.', 'while', 'the', 'fantasy', 'land', 'of', 'narnia', 'is', 'an', 'alternate', 'universe', 'and', 'the', 'lord', 'of', 'the', 'rings', "'", 'middle-earth', 'a', 'mythic', 'past', ',', 'the', 'wizarding', 'world', 'of', 'harry', 'potter', 'exists', 'parallel', 'to', 'the', 'real', 'world', 'and', 'contains', 'magical', 'versions', 'of', 'the', 'ordinary', 'elements', 'of', 'everyday', 'life', ',', 'with', 'the', 'action', 'mostly', 'set', 'in', 'scotland', '(', 'hogwarts', ')', ',', 'the', 'west', 'country', ',', 'devon', ',', 'london', ',', 'and', 'surrey', 'in', 'southeast', 'england', '.', 'the', 'world', 'only', 'accessible', 'to', 'wizards', 'and', 'magical', 'beings', 'comprises', 'a', 'fragmented', 'collection', 'of', 'overlooked', 'hidden', 'streets', ',', 'ancient', 'pubs', ',', 'lonely', 'country', 'manors', ',', 'and', 'secluded', 'castles', 'invisible', 'to', 'the', 'muggle', 'population', '.']

# %%
# remove all tokens that are not alphabetic
words = [word for word in tokens if word.isalpha()]
print(len(words))
print(words[:319])
# Out:
# 363
# ['the', 'central', 'character', 'in', 'the', 'series', 'is', 'harry', 'potter', 'a', 'boy', 'who', 'lives', 'in', 'the', 'fictional', 'town', 'of', 'little', 'whinging', 'surrey', 'with', 'his', 'aunt', 'uncle', 'and', 'cousin', 'the', 'dursleys', 'and', 'discovers', 'at', 'the', 'age', 'of', 'eleven', 'that', 'he', 'is', 'a', 'wizard', 'though', 'he', 'lives', 'in', 'the', 'ordinary', 'world', 'of', 'people', 'known', 'as', 'muggles', 'the', 'wizarding', 'world', 'exists', 'parallel', 'to', 'the', 'muggle', 'world', 'albeit', 'hidden', 'and', 'in', 'secrecy', 'his', 'magical', 'ability', 'is', 'inborn', 'and', 'children', 'with', 'such', 'abilities', 'are', 'invited', 'to', 'attend', 'exclusive', 'magic', 'schools', 'that', 'teach', 'the', 'necessary', 'skills', 'to', 'succeed', 'in', 'the', 'wizarding', 'world', 'harry', 'becomes', 'a', 'student', 'at', 'hogwarts', 'school', 'of', 'witchcraft', 'and', 'wizardry', 'a', 'wizarding', 'academy', 'in', 'scotland', 'and', 'it', 'is', 'here', 'where', 'most', 'of', 'the', 'events', 'in', 'the', 'series', 'take', 'place', 'as', 'harry', 'develops', 'through', 'his', 'adolescence', 'he', 'learns', 'to', 'overcome', 'the', 'problems', 'that', 'face', 'him', 'magical', 'social', 'and', 'emotional', 'including', 'ordinary', 'teenage', 'challenges', 'such', 'as', 'friendships', 'infatuation', 'romantic', 'relationships', 'schoolwork', 'and', 'exams', 'anxiety', 'depression', 'stress', 'and', 'the', 'greater', 'test', 'of', 'preparing', 'himself', 'for', 'the', 'confrontation', 'that', 'lies', 'ahead', 'in', 'wizarding', 'britain', 'second', 'wizarding', 'war', 'each', 'novel', 'chronicles', 'one', 'year', 'in', 'harry', 'life', 'during', 'the', 'period', 'from', 'to', 'the', 'books', 'also', 'contain', 'many', 'flashbacks', 'which', 'are', 'frequently', 'experienced', 'by', 'harry', 'viewing', 'the', 'memories', 'of', 'other', 'characters', 'in', 'a', 'device', 'called', 'a', 'pensieve', 'the', 'environment', 'rowling', 'created', 'is', 'intimately', 'connected', 'to', 'reality', 'the', 'british', 'magical', 'community', 'of', 'the', 'harry', 'potter', 'books', 'is', 'inspired', 'by', 'british', 'culture', 'european', 'folklore', 'classical', 'mythology', 'and', 'alchemy', 'incorporating', 'objects', 'and', 'wildlife', 'such', 'as', 'magic', 'wands', 'magic', 'plants', 'potions', 'spells', 'flying', 'broomsticks', 'centaurs', 'and', 'other', 'magical', 'creatures', 'and', 'the', 'philosopher', 'stone', 'beside', 'others', 'invented', 'by', 'rowling', 'while', 'the', 'fantasy', 'land', 'of', 'narnia', 'is', 'an', 'alternate', 'universe', 'and', 'the', 'lord', 'of', 'the', 'rings', 'a', 'mythic', 'past', 'the', 'wizarding', 'world', 'of', 'harry', 'potter', 'exists', 'parallel', 'to', 'the', 'real', 'world', 'and', 'contains', 'magical', 'versions', 'of', 'the', 'ordinary', 'elements', 'of', 'everyday', 'life', 'with', 'the', 'action', 'mostly']

# %%
from nltk.corpus import stopwords
nltk.download('stopwords')
stop_words = stopwords.words('english')
print(stop_words)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %%
words = [w for w in words if not w in stop_words]
print(words[:100])
# Out:
# ['central', 'character', 'series', 'harry', 'potter', 'boy', 'lives', 'fictional', 'town', 'little', 'whinging', 'surrey', 'aunt', 'uncle', 'cousin', 'dursleys', 'discovers', 'age', 'eleven', 'wizard', 'though', 'lives', 'ordinary', 'world', 'people', 'known', 'muggles', 'wizarding', 'world', 'exists', 'parallel', 'muggle', 'world', 'albeit', 'hidden', 'secrecy', 'magical', 'ability', 'inborn', 'children', 'abilities', 'invited', 'attend', 'exclusive', 'magic', 'schools', 'teach', 'necessary', 'skills', 'succeed', 'wizarding', 'world', 'harry', 'becomes', 'student', 'hogwarts', 'school', 'witchcraft', 'wizardry', 'wizarding', 'academy', 'scotland', 'events', 'series', 'take', 'place', 'harry', 'develops', 'adolescence', 'learns', 'overcome', 'problems', 'face', 'magical', 'social', 'emotional', 'including', 'ordinary', 'teenage', 'challenges', 'friendships', 'infatuation', 'romantic', 'relationships', 'schoolwork', 'exams', 'anxiety', 'depression', 'stress', 'greater', 'test', 'preparing', 'confrontation', 'lies', 'ahead', 'wizarding', 'britain', 'second', 'wizarding', 'war']

# %%
#POS Tagging
nltk.pos_tag(words)
# Out:
# [('central', 'JJ'),
#  ('character', 'NN'),
#  ('series', 'NN'),
#  ('harry', 'VBP'),
#  ('potter', 'JJ'),
#  ('boy', 'NN'),
#  ('lives', 'VBZ'),
#  ('fictional', 'JJ'),
#  ('town', 'NN'),
#  ('little', 'JJ'),
#  ('whinging', 'VBG'),
#  ('surrey', 'JJ'),
#  ('aunt', 'NN'),
#  ('uncle', 'NN'),
#  ('cousin', 'NN'),
#  ('dursleys', 'NN'),
#  ('discovers', 'NNS'),
#  ('age', 'NN'),
#  ('eleven', 'RB'),
#  ('wizard', 'RB'),
#  ('though', 'IN'),
#  ('lives', 'NNS'),
#  ('ordinary', 'JJ'),
#  ('world', 'NN'),
#  ('people', 'NNS'),
#  ('known', 'VBN'),
#  ('muggles', 'NNS'),
#  ('wizarding', 'VBG'),
#  ('world', 'NN'),
#  ('exists', 'VBZ'),
#  ('parallel', 'JJ'),
#  ('muggle', 'NN'),
#  ('world', 'NN'),
#  ('albeit', 'IN'),
#  ('hidden', 'JJ'),
#  ('secrecy', 'JJ'),
#  ('magical', 'JJ'),
#  ('ability', 'NN'),
#  ('inborn', 'JJ'),
#  ('children', 'NNS'),
#  ('abilities', 'NNS'),
#  ('invited', 'VBD'),
#  ('attend', 'JJ'),
#  ('exclusive', 'JJ'),
#  ('magic', 'NN'),
#  ('schools', 'NNS'),
#  ('teach', 'VBP'),
#  ('necessary', 'JJ'),
#  ('skills', 'NNS'),
#  ('succeed', 'VB'),
#  ('wizarding', 'VBG'),
#  ('world', 'NN'),
#  ('harry', 'NN'),
#  ('becomes', 'VBZ'),
#  ('student', 'JJ'),
#  ('hogwarts', 'NNS'),
#  ('school', 'NN'),
#  ('witchcraft', 'NN'),
#  ('wizardry', 'NN'),
#  ('wizarding', 'VBG'),
#  ('academy', 'JJ'),
#  ('scotland', 'NN'),
#  ('events', 'NNS'),
#  ('series', 'NN'),
#  ('take', 'VBP'),
#  ('place', 'NN'),
#  ('harry', 'NN'),
#  ('develops', 'VBZ'),
#  ('adolescence', 'NN'),
#  ('learns', 'VBZ'),
#  ('overcome', 'JJ'),
#  ('problems', 'NNS'),
#  ('face', 'VBP'),
#  ('magical', 'JJ'),
#  ('social', 'JJ'),
#  ('emotional', 'JJ'),
#  ('including', 'VBG'),
#  ('ordinary', 'JJ'),
#  ('teenage', 'NN'),
#  ('challenges', 'NNS'),
#  ('friendships', 'VBP'),
#  ('infatuation', 'NN'),
#  ('romantic', 'JJ'),
#  ('relationships', 'NNS'),
#  ('schoolwork', 'VBP'),
#  ('exams', 'JJ'),
#  ('anxiety', 'NN'),
#  ('depression', 'NN'),
#  ('stress', 'NN'),
#  ('greater', 'JJR'),
#  ('test', 'NN'),
#  ('preparing', 'VBG'),
#  ('confrontation', 'NN'),
#  ('lies', 'VBZ'),
#  ('ahead', 'RB'),
#  ('wizarding', 'VBG'),
#  ('britain', 'JJ'),
#  ('second', 'JJ'),
#  ('wizarding', 'VBG'),
#  ('war', 'NN'),
#  ('novel', 'NN'),
#  ('chronicles', 'NNS'),
#  ('one', 'CD'),
#  ('year', 'NN'),
#  ('harry', 'NN'),
#  ('life', 'NN'),
#  ('period', 'NN'),
#  ('books', 'NNS'),
#  ('also', 'RB'),
#  ('contain', 'VBP'),
#  ('many', 'JJ'),
#  ('flashbacks', 'NNS'),
#  ('frequently', 'RB'),
#  ('experienced', 'VBD'),
#  ('harry', 'NN'),
#  ('viewing', 'VBG'),
#  ('memories', 'NNS'),
#  ('characters', 'NNS'),
#  ('device', 'RB'),
#  ('called', 'VBD'),
#  ('pensieve', 'JJ'),
#  ('environment', 'NN'),
#  ('rowling', 'VBG'),
#  ('created', 'VBN'),
#  ('intimately', 'RB'),
#  ('connected', 'VBN'),
#  ('reality', 'NN'),
#  ('british', 'JJ'),
#  ('magical', 'JJ'),
#  ('community', 'NN'),
#  ('harry', 'VBP'),
#  ('potter', 'NN'),
#  ('books', 'NNS'),
#  ('inspired', 'VBD'),
#  ('british', 'JJ'),
#  ('culture', 'NN'),
#  ('european', 'JJ'),
#  ('folklore', 'RB'),
#  ('classical', 'JJ'),
#  ('mythology', 'NN'),
#  ('alchemy', 'NN'),
#  ('incorporating', 'VBG'),
#  ('objects', 'NNS'),
#  ('wildlife', 'JJ'),
#  ('magic', 'JJ'),
#  ('wands', 'NNS'),
#  ('magic', 'JJ'),
#  ('plants', 'NNS'),
#  ('potions', 'NNS'),
#  ('spells', 'NNS'),
#  ('flying', 'VBG'),
#  ('broomsticks', 'NNS'),
#  ('centaurs', 'VBP'),
#  ('magical', 'JJ'),
#  ('creatures', 'NNS'),
#  ('philosopher', 'VBP'),
#  ('stone', 'NN'),
#  ('beside', 'NN'),
#  ('others', 'NNS'),
#  ('invented', 'VBD'),
#  ('rowling', 'VBG'),
#  ('fantasy', 'JJ'),
#  ('land', 'NN'),
#  ('narnia', 'NN'),
#  ('alternate', 'VBP'),
#  ('universe', 'JJ'),
#  ('lord', 'NN'),
#  ('rings', 'NNS'),
#  ('mythic', 'JJ'),
#  ('past', 'IN'),
#  ('wizarding', 'VBG'),
#  ('world', 'NN'),
#  ('harry', 'NN'),
#  ('potter', 'NN'),
#  ('exists', 'VBZ'),
#  ('parallel', 'RB'),
#  ('real', 'JJ'),
#  ('world', 'NN'),
#  ('contains', 'VBZ'),
#  ('magical', 'JJ'),
#  ('versions', 'NNS'),
#  ('ordinary', 'JJ'),
#  ('elements', 'NNS'),
#  ('everyday', 'JJ'),
#  ('life', 'NN'),
#  ('action', 'NN'),
#  ('mostly', 'RB'),
#  ('set', 'VBN'),
#  ('scotland', 'NN'),
#  ('hogwarts', 'NNS'),
#  ('west', 'VBP'),
#  ('country', 'NN'),
#  ('devon', 'JJ'),
#  ('london', 'NN'),
#  ('surrey', 'VBD'),
#  ('southeast', 'JJ'),
#  ('england', 'NN'),
#  ('world', 'NN'),
#  ('accessible', 'JJ'),
#  ('wizards', 'NNS'),
#  ('magical', 'JJ'),
#  ('beings', 'NNS'),
#  ('comprises', 'NNS'),
#  ('fragmented', 'VBD'),
#  ('collection', 'NN'),
#  ('overlooked', 'VBD'),
#  ('hidden', 'JJ'),
#  ('streets', 'NNS'),
#  ('ancient', 'JJ'),
#  ('pubs', 'NNS'),
#  ('lonely', 'RB'),
#  ('country', 'NN'),
#  ('manors', 'NNS'),
#  ('secluded', 'VBD'),
#  ('castles', 'NNS'),
#  ('invisible', 'JJ'),
#  ('muggle', 'JJ'),
#  ('population', 'NN')]

# %%
from nltk.stem import PorterStemmer
from nltk.tokenize import sent_tokenize, word_tokenize

ps = PorterStemmer()

stemmed_words=[]
for w in words:
    stemmed_words.append(ps.stem(w))

print("Filtered Sentence:",words)
print("Stemmed Sentence:",stemmed_words)
# Out:
# Filtered Sentence: ['central', 'character', 'series', 'harry', 'potter', 'boy', 'lives', 'fictional', 'town', 'little', 'whinging', 'surrey', 'aunt', 'uncle', 'cousin', 'dursleys', 'discovers', 'age', 'eleven', 'wizard', 'though', 'lives', 'ordinary', 'world', 'people', 'known', 'muggles', 'wizarding', 'world', 'exists', 'parallel', 'muggle', 'world', 'albeit', 'hidden', 'secrecy', 'magical', 'ability', 'inborn', 'children', 'abilities', 'invited', 'attend', 'exclusive', 'magic', 'schools', 'teach', 'necessary', 'skills', 'succeed', 'wizarding', 'world', 'harry', 'becomes', 'student', 'hogwarts', 'school', 'witchcraft', 'wizardry', 'wizarding', 'academy', 'scotland', 'events', 'series', 'take', 'place', 'harry', 'develops', 'adolescence', 'learns', 'overcome', 'problems', 'face', 'magical', 'social', 'emotional', 'including', 'ordinary', 'teenage', 'challenges', 'friendships', 'infatuation', 'romantic', 'relationships', 'schoolwork', 'exams', 'anxiety', 'depression', 'stress', 'greater', 'test', 'preparing', 'confrontation', 'lies', 'ahead', 'wizarding', 'britain', 'second', 'wizarding', 'war', 'novel', 'chronicles', 'one', 'year', 'harry', 'life', 'period', 'books', 'also', 'contain', 'many', 'flashbacks', 'frequently', 'experienced', 'harry', 'viewing', 'memories', 'characters', 'device', 'called', 'pensieve', 'environment', 'rowling', 'created', 'intimately', 'connected', 'reality', 'british', 'magical', 'community', 'harry', 'potter', 'books', 'inspired', 'british', 'culture', 'european', 'folklore', 'classical', 'mythology', 'alchemy', 'incorporating', 'objects', 'wildlife', 'magic', 'wands', 'magic', 'plants', 'potions', 'spells', 'flying', 'broomsticks', 'centaurs', 'magical', 'creatures', 'philosopher', 'stone', 'beside', 'others', 'invented', 'rowling', 'fantasy', 'land', 'narnia', 'alternate', 'universe', 'lord', 'rings', 'mythic', 'past', 'wizarding', 'world', 'harry', 'potter', 'exists', 'parallel', 'real', 'world', 'contains', 'magical', 'versions', 'ordinary', 'elements', 'everyday', 'life', 'action', 'mostly', 'set', 'scotland', 'hogwarts', 'west', 'country', 'devon', 'london', 'surrey', 'southeast', 'england', 'world', 'accessible', 'wizards', 'magical', 'beings', 'comprises', 'fragmented', 'collection', 'overlooked', 'hidden', 'streets', 'ancient', 'pubs', 'lonely', 'country', 'manors', 'secluded', 'castles', 'invisible', 'muggle', 'population']
# Stemmed Sentence: ['central', 'charact', 'seri', 'harri', 'potter', 'boy', 'live', 'fiction', 'town', 'littl', 'whing', 'surrey', 'aunt', 'uncl', 'cousin', 'dursley', 'discov', 'age', 'eleven', 'wizard', 'though', 'live', 'ordinari', 'world', 'peopl', 'known', 'muggl', 'wizard', 'world', 'exist', 'parallel', 'muggl', 'world', 'albeit', 'hidden', 'secreci', 'magic', 'abil', 'inborn', 'children', 'abil', 'invit', 'attend', 'exclus', 'magic', 'school', 'teach', 'necessari', 'skill', 'succeed', 'wizard', 'world', 'harri', 'becom', 'student', 'hogwart', 'school', 'witchcraft', 'wizardri', 'wizard', 'academi', 'scotland', 'event', 'seri', 'take', 'place', 'harri', 'develop', 'adolesc', 'learn', 'overcom', 'problem', 'face', 'magic', 'social', 'emot', 'includ', 'ordinari', 'teenag', 'challeng', 'friendship', 'infatu', 'romant', 'relationship', 'schoolwork', 'exam', 'anxieti', 'depress', 'stress', 'greater', 'test', 'prepar', 'confront', 'lie', 'ahead', 'wizard', 'britain', 'second', 'wizard', 'war', 'novel', 'chronicl', 'one', 'year', 'harri', 'life', 'period', 'book', 'also', 'contain', 'mani', 'flashback', 'frequent', 'experienc', 'harri', 'view', 'memori', 'charact', 'devic', 'call', 'pensiev', 'environ', 'rowl', 'creat', 'intim', 'connect', 'realiti', 'british', 'magic', 'commun', 'harri', 'potter', 'book', 'inspir', 'british', 'cultur', 'european', 'folklor', 'classic', 'mytholog', 'alchemi', 'incorpor', 'object', 'wildlif', 'magic', 'wand', 'magic', 'plant', 'potion', 'spell', 'fli', 'broomstick', 'centaur', 'magic', 'creatur', 'philosoph', 'stone', 'besid', 'other', 'invent', 'rowl', 'fantasi', 'land', 'narnia', 'altern', 'univers', 'lord', 'ring', 'mythic', 'past', 'wizard', 'world', 'harri', 'potter', 'exist', 'parallel', 'real', 'world', 'contain', 'magic', 'version', 'ordinari', 'element', 'everyday', 'life', 'action', 'mostli', 'set', 'scotland', 'hogwart', 'west', 'countri', 'devon', 'london', 'surrey', 'southeast', 'england', 'world', 'access', 'wizard', 'magic', 'be', 'compris', 'fragment', 'collect', 'overlook', 'hidden', 'street', 'ancient', 'pub', 'lone', 'countri', 'manor', 'seclud', 'castl', 'invis', 'muggl', 'popul']

# %%
#Lemmatization
from nltk.stem.wordnet import WordNetLemmatizer
lem = WordNetLemmatizer()

word = "divided"
print("Lemmatized Word:",lem.lemmatize(word,"v"))
print("Stemmed Word:",ps.stem(word))
# Out:
# Lemmatized Word: divide
# Stemmed Word: divid

# %%
from nltk.probability import FreqDist
Counter = FreqDist(stemmed)
most_occur = Counter.most_common(10)
print(most_occur)
# Out:
# [('magic', 9), ('wizard', 8), ('harri', 7), ('world', 7), ('potter', 3), ('ordinari', 3), ('muggl', 3), ('charact', 2), ('seri', 2), ('live', 2)]

# %%
import matplotlib.pyplot as plt
Counter.plot(30,cumulative=False)
plt.show()

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
stopwords = set(STOPWORDS)

# %%
import sys
print(sys.executable)
# Out:
# /usr/bin/python3

# %%
def show_wordcloud(data, title = None):
    wordcloud = WordCloud(
        background_color='white',
        stopwords=stopwords,
        max_words=200,
        max_font_size=40, 
        scale=3,
        random_state=1 # chosen at random by flipping a coin; it was heads
    ).generate(str(data))

    fig = plt.figure(1, figsize=(12, 12))
    plt.axis('off')
    if title: 
        fig.suptitle(title, fontsize=20)
        fig.subplots_adjust(top=2.3)

    plt.imshow(wordcloud)
    plt.show()

# %%
show_wordcloud(stemmed)

# %%
text
# Out:
# "The central character in the series is Harry Potter, a boy who lives in the fictional town of Little Whinging, Surrey with his aunt, uncle, and cousin – the Dursleys – and discovers at the age of eleven that he is a wizard, though he lives in the ordinary world of non-magical people known as Muggles. The wizarding world exists parallel to the Muggle world, albeit hidden and in secrecy. His magical ability is inborn, and children with such abilities are invited to attend exclusive magic schools that teach the necessary skills to succeed in the wizarding world.\n\nHarry becomes a student at Hogwarts School of Witchcraft and Wizardry, a wizarding academy in Scotland, and it is here where most of the events in the series take place. As Harry develops through his adolescence, he learns to overcome the problems that face him: magical, social, and emotional, including ordinary teenage challenges such as friendships, infatuation, romantic relationships, schoolwork and exams, anxiety, depression, stress, and the greater test of preparing himself for the confrontation that lies ahead in wizarding Britain's increasingly-violent second wizarding war.\n\nEach novel chronicles one year in Harry's life during the period from 1991 to 1998. The books also contain many flashbacks, which are frequently experienced by Harry viewing the memories of other characters in a device called a Pensieve.\n\nThe environment Rowling created is intimately connected to reality. The British magical community of the Harry Potter books is inspired by 1990s British culture, European folklore, classical mythology and alchemy, incorporating objects and wildlife such as magic wands, magic plants, potions, spells, flying broomsticks, centaurs and other magical creatures, and the Philosopher's Stone, beside others invented by Rowling. While the fantasy land of Narnia is an alternate universe and the Lord of the Rings' Middle-earth a mythic past, the wizarding world of Harry Potter exists parallel to the real world and contains magical versions of the ordinary elements of everyday life, with the action mostly set in Scotland (Hogwarts), the West Country, Devon, London, and Surrey in southeast England. The world only accessible to wizards and magical beings comprises a fragmented collection of overlooked hidden streets, ancient pubs, lonely country manors, and secluded castles invisible to the Muggle population."

# %%
# split into sentences
sentences = sent_tokenize(text)
print(sentences[0])
# Out:
# The central character in the series is Harry Potter, a boy who lives in the fictional town of Little Whinging, Surrey with his aunt, uncle, and cousin – the Dursleys – and discovers at the age of eleven that he is a wizard, though he lives in the ordinary world of non-magical people known as Muggles.

# %%
from nltk.tokenize import word_tokenize
tokens = word_tokenize(text)
print(len(tokens))
print(tokens[:374])
# Out:
# 429
# ['The', 'central', 'character', 'in', 'the', 'series', 'is', 'Harry', 'Potter', ',', 'a', 'boy', 'who', 'lives', 'in', 'the', 'fictional', 'town', 'of', 'Little', 'Whinging', ',', 'Surrey', 'with', 'his', 'aunt', ',', 'uncle', ',', 'and', 'cousin', '–', 'the', 'Dursleys', '–', 'and', 'discovers', 'at', 'the', 'age', 'of', 'eleven', 'that', 'he', 'is', 'a', 'wizard', ',', 'though', 'he', 'lives', 'in', 'the', 'ordinary', 'world', 'of', 'non-magical', 'people', 'known', 'as', 'Muggles', '.', 'The', 'wizarding', 'world', 'exists', 'parallel', 'to', 'the', 'Muggle', 'world', ',', 'albeit', 'hidden', 'and', 'in', 'secrecy', '.', 'His', 'magical', 'ability', 'is', 'inborn', ',', 'and', 'children', 'with', 'such', 'abilities', 'are', 'invited', 'to', 'attend', 'exclusive', 'magic', 'schools', 'that', 'teach', 'the', 'necessary', 'skills', 'to', 'succeed', 'in', 'the', 'wizarding', 'world', '.', 'Harry', 'becomes', 'a', 'student', 'at', 'Hogwarts', 'School', 'of', 'Witchcraft', 'and', 'Wizardry', ',', 'a', 'wizarding', 'academy', 'in', 'Scotland', ',', 'and', 'it', 'is', 'here', 'where', 'most', 'of', 'the', 'events', 'in', 'the', 'series', 'take', 'place', '.', 'As', 'Harry', 'develops', 'through', 'his', 'adolescence', ',', 'he', 'learns', 'to', 'overcome', 'the', 'problems', 'that', 'face', 'him', ':', 'magical', ',', 'social', ',', 'and', 'emotional', ',', 'including', 'ordinary', 'teenage', 'challenges', 'such', 'as', 'friendships', ',', 'infatuation', ',', 'romantic', 'relationships', ',', 'schoolwork', 'and', 'exams', ',', 'anxiety', ',', 'depression', ',', 'stress', ',', 'and', 'the', 'greater', 'test', 'of', 'preparing', 'himself', 'for', 'the', 'confrontation', 'that', 'lies', 'ahead', 'in', 'wizarding', 'Britain', "'s", 'increasingly-violent', 'second', 'wizarding', 'war', '.', 'Each', 'novel', 'chronicles', 'one', 'year', 'in', 'Harry', "'s", 'life', 'during', 'the', 'period', 'from', '1991', 'to', '1998', '.', 'The', 'books', 'also', 'contain', 'many', 'flashbacks', ',', 'which', 'are', 'frequently', 'experienced', 'by', 'Harry', 'viewing', 'the', 'memories', 'of', 'other', 'characters', 'in', 'a', 'device', 'called', 'a', 'Pensieve', '.', 'The', 'environment', 'Rowling', 'created', 'is', 'intimately', 'connected', 'to', 'reality', '.', 'The', 'British', 'magical', 'community', 'of', 'the', 'Harry', 'Potter', 'books', 'is', 'inspired', 'by', '1990s', 'British', 'culture', ',', 'European', 'folklore', ',', 'classical', 'mythology', 'and', 'alchemy', ',', 'incorporating', 'objects', 'and', 'wildlife', 'such', 'as', 'magic', 'wands', ',', 'magic', 'plants', ',', 'potions', ',', 'spells', ',', 'flying', 'broomsticks', ',', 'centaurs', 'and', 'other', 'magical', 'creatures', ',', 'and', 'the', 'Philosopher', "'s", 'Stone', ',', 'beside', 'others', 'invented', 'by', 'Rowling', '.', 'While', 'the', 'fantasy', 'land', 'of', 'Narnia', 'is', 'an', 'alternate', 'universe', 'and', 'the', 'Lord', 'of', 'the', 'Rings', "'", 'Middle-earth', 'a', 'mythic', 'past', ',', 'the', 'wizarding', 'world', 'of', 'Harry', 'Potter', 'exists', 'parallel', 'to', 'the', 'real', 'world', 'and', 'contains', 'magical', 'versions', 'of', 'the', 'ordinary', 'elements', 'of', 'everyday', 'life', ',', 'with', 'the', 'action', 'mostly']

# %%
# convert to lower case
tokens = [w.lower() for w in tokens]
print(tokens)
# Out:
# ['the', 'central', 'character', 'in', 'the', 'series', 'is', 'harry', 'potter', ',', 'a', 'boy', 'who', 'lives', 'in', 'the', 'fictional', 'town', 'of', 'little', 'whinging', ',', 'surrey', 'with', 'his', 'aunt', ',', 'uncle', ',', 'and', 'cousin', '–', 'the', 'dursleys', '–', 'and', 'discovers', 'at', 'the', 'age', 'of', 'eleven', 'that', 'he', 'is', 'a', 'wizard', ',', 'though', 'he', 'lives', 'in', 'the', 'ordinary', 'world', 'of', 'non-magical', 'people', 'known', 'as', 'muggles', '.', 'the', 'wizarding', 'world', 'exists', 'parallel', 'to', 'the', 'muggle', 'world', ',', 'albeit', 'hidden', 'and', 'in', 'secrecy', '.', 'his', 'magical', 'ability', 'is', 'inborn', ',', 'and', 'children', 'with', 'such', 'abilities', 'are', 'invited', 'to', 'attend', 'exclusive', 'magic', 'schools', 'that', 'teach', 'the', 'necessary', 'skills', 'to', 'succeed', 'in', 'the', 'wizarding', 'world', '.', 'harry', 'becomes', 'a', 'student', 'at', 'hogwarts', 'school', 'of', 'witchcraft', 'and', 'wizardry', ',', 'a', 'wizarding', 'academy', 'in', 'scotland', ',', 'and', 'it', 'is', 'here', 'where', 'most', 'of', 'the', 'events', 'in', 'the', 'series', 'take', 'place', '.', 'as', 'harry', 'develops', 'through', 'his', 'adolescence', ',', 'he', 'learns', 'to', 'overcome', 'the', 'problems', 'that', 'face', 'him', ':', 'magical', ',', 'social', ',', 'and', 'emotional', ',', 'including', 'ordinary', 'teenage', 'challenges', 'such', 'as', 'friendships', ',', 'infatuation', ',', 'romantic', 'relationships', ',', 'schoolwork', 'and', 'exams', ',', 'anxiety', ',', 'depression', ',', 'stress', ',', 'and', 'the', 'greater', 'test', 'of', 'preparing', 'himself', 'for', 'the', 'confrontation', 'that', 'lies', 'ahead', 'in', 'wizarding', 'britain', "'s", 'increasingly-violent', 'second', 'wizarding', 'war', '.', 'each', 'novel', 'chronicles', 'one', 'year', 'in', 'harry', "'s", 'life', 'during', 'the', 'period', 'from', '1991', 'to', '1998', '.', 'the', 'books', 'also', 'contain', 'many', 'flashbacks', ',', 'which', 'are', 'frequently', 'experienced', 'by', 'harry', 'viewing', 'the', 'memories', 'of', 'other', 'characters', 'in', 'a', 'device', 'called', 'a', 'pensieve', '.', 'the', 'environment', 'rowling', 'created', 'is', 'intimately', 'connected', 'to', 'reality', '.', 'the', 'british', 'magical', 'community', 'of', 'the', 'harry', 'potter', 'books', 'is', 'inspired', 'by', '1990s', 'british', 'culture', ',', 'european', 'folklore', ',', 'classical', 'mythology', 'and', 'alchemy', ',', 'incorporating', 'objects', 'and', 'wildlife', 'such', 'as', 'magic', 'wands', ',', 'magic', 'plants', ',', 'potions', ',', 'spells', ',', 'flying', 'broomsticks', ',', 'centaurs', 'and', 'other', 'magical', 'creatures', ',', 'and', 'the', 'philosopher', "'s", 'stone', ',', 'beside', 'others', 'invented', 'by', 'rowling', '.', 'while', 'the', 'fantasy', 'land', 'of', 'narnia', 'is', 'an', 'alternate', 'universe', 'and', 'the', 'lord', 'of', 'the', 'rings', "'", 'middle-earth', 'a', 'mythic', 'past', ',', 'the', 'wizarding', 'world', 'of', 'harry', 'potter', 'exists', 'parallel', 'to', 'the', 'real', 'world', 'and', 'contains', 'magical', 'versions', 'of', 'the', 'ordinary', 'elements', 'of', 'everyday', 'life', ',', 'with', 'the', 'action', 'mostly', 'set', 'in', 'scotland', '(', 'hogwarts', ')', ',', 'the', 'west', 'country', ',', 'devon', ',', 'london', ',', 'and', 'surrey', 'in', 'southeast', 'england', '.', 'the', 'world', 'only', 'accessible', 'to', 'wizards', 'and', 'magical', 'beings', 'comprises', 'a', 'fragmented', 'collection', 'of', 'overlooked', 'hidden', 'streets', ',', 'ancient', 'pubs', ',', 'lonely', 'country', 'manors', ',', 'and', 'secluded', 'castles', 'invisible', 'to', 'the', 'muggle', 'population', '.']

# %%
# remove all tokens that are not alphabetic
words = [word for word in tokens if word.isalpha()]
print(len(words))
print(words[:319])
# Out:
# 363
# ['the', 'central', 'character', 'in', 'the', 'series', 'is', 'harry', 'potter', 'a', 'boy', 'who', 'lives', 'in', 'the', 'fictional', 'town', 'of', 'little', 'whinging', 'surrey', 'with', 'his', 'aunt', 'uncle', 'and', 'cousin', 'the', 'dursleys', 'and', 'discovers', 'at', 'the', 'age', 'of', 'eleven', 'that', 'he', 'is', 'a', 'wizard', 'though', 'he', 'lives', 'in', 'the', 'ordinary', 'world', 'of', 'people', 'known', 'as', 'muggles', 'the', 'wizarding', 'world', 'exists', 'parallel', 'to', 'the', 'muggle', 'world', 'albeit', 'hidden', 'and', 'in', 'secrecy', 'his', 'magical', 'ability', 'is', 'inborn', 'and', 'children', 'with', 'such', 'abilities', 'are', 'invited', 'to', 'attend', 'exclusive', 'magic', 'schools', 'that', 'teach', 'the', 'necessary', 'skills', 'to', 'succeed', 'in', 'the', 'wizarding', 'world', 'harry', 'becomes', 'a', 'student', 'at', 'hogwarts', 'school', 'of', 'witchcraft', 'and', 'wizardry', 'a', 'wizarding', 'academy', 'in', 'scotland', 'and', 'it', 'is', 'here', 'where', 'most', 'of', 'the', 'events', 'in', 'the', 'series', 'take', 'place', 'as', 'harry', 'develops', 'through', 'his', 'adolescence', 'he', 'learns', 'to', 'overcome', 'the', 'problems', 'that', 'face', 'him', 'magical', 'social', 'and', 'emotional', 'including', 'ordinary', 'teenage', 'challenges', 'such', 'as', 'friendships', 'infatuation', 'romantic', 'relationships', 'schoolwork', 'and', 'exams', 'anxiety', 'depression', 'stress', 'and', 'the', 'greater', 'test', 'of', 'preparing', 'himself', 'for', 'the', 'confrontation', 'that', 'lies', 'ahead', 'in', 'wizarding', 'britain', 'second', 'wizarding', 'war', 'each', 'novel', 'chronicles', 'one', 'year', 'in', 'harry', 'life', 'during', 'the', 'period', 'from', 'to', 'the', 'books', 'also', 'contain', 'many', 'flashbacks', 'which', 'are', 'frequently', 'experienced', 'by', 'harry', 'viewing', 'the', 'memories', 'of', 'other', 'characters', 'in', 'a', 'device', 'called', 'a', 'pensieve', 'the', 'environment', 'rowling', 'created', 'is', 'intimately', 'connected', 'to', 'reality', 'the', 'british', 'magical', 'community', 'of', 'the', 'harry', 'potter', 'books', 'is', 'inspired', 'by', 'british', 'culture', 'european', 'folklore', 'classical', 'mythology', 'and', 'alchemy', 'incorporating', 'objects', 'and', 'wildlife', 'such', 'as', 'magic', 'wands', 'magic', 'plants', 'potions', 'spells', 'flying', 'broomsticks', 'centaurs', 'and', 'other', 'magical', 'creatures', 'and', 'the', 'philosopher', 'stone', 'beside', 'others', 'invented', 'by', 'rowling', 'while', 'the', 'fantasy', 'land', 'of', 'narnia', 'is', 'an', 'alternate', 'universe', 'and', 'the', 'lord', 'of', 'the', 'rings', 'a', 'mythic', 'past', 'the', 'wizarding', 'world', 'of', 'harry', 'potter', 'exists', 'parallel', 'to', 'the', 'real', 'world', 'and', 'contains', 'magical', 'versions', 'of', 'the', 'ordinary', 'elements', 'of', 'everyday', 'life', 'with', 'the', 'action', 'mostly']

# %%
from nltk.corpus import stopwords
nltk.download('stopwords')
stop_words = stopwords.words('english')
print(stop_words)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %%
words = [w for w in words if not w in stop_words]
print(words[:100])
# Out:
# ['central', 'character', 'series', 'harry', 'potter', 'boy', 'lives', 'fictional', 'town', 'little', 'whinging', 'surrey', 'aunt', 'uncle', 'cousin', 'dursleys', 'discovers', 'age', 'eleven', 'wizard', 'though', 'lives', 'ordinary', 'world', 'people', 'known', 'muggles', 'wizarding', 'world', 'exists', 'parallel', 'muggle', 'world', 'albeit', 'hidden', 'secrecy', 'magical', 'ability', 'inborn', 'children', 'abilities', 'invited', 'attend', 'exclusive', 'magic', 'schools', 'teach', 'necessary', 'skills', 'succeed', 'wizarding', 'world', 'harry', 'becomes', 'student', 'hogwarts', 'school', 'witchcraft', 'wizardry', 'wizarding', 'academy', 'scotland', 'events', 'series', 'take', 'place', 'harry', 'develops', 'adolescence', 'learns', 'overcome', 'problems', 'face', 'magical', 'social', 'emotional', 'including', 'ordinary', 'teenage', 'challenges', 'friendships', 'infatuation', 'romantic', 'relationships', 'schoolwork', 'exams', 'anxiety', 'depression', 'stress', 'greater', 'test', 'preparing', 'confrontation', 'lies', 'ahead', 'wizarding', 'britain', 'second', 'wizarding', 'war']

# %%
#from nltk.stem.porter import PorterStemmer
from nltk.stem.snowball import SnowballStemmer
#porter = PorterStemmer()
stemmer = SnowballStemmer("english")
#stemmed = [porter.stem(word) for word in words]
stemmed = [stemmer.stem(word) for word in words]
print(len(stemmed))
print(stemmed[:186])
# Out:
# 218
# ['central', 'charact', 'seri', 'harri', 'potter', 'boy', 'live', 'fiction', 'town', 'littl', 'whing', 'surrey', 'aunt', 'uncl', 'cousin', 'dursley', 'discov', 'age', 'eleven', 'wizard', 'though', 'live', 'ordinari', 'world', 'peopl', 'known', 'muggl', 'wizard', 'world', 'exist', 'parallel', 'muggl', 'world', 'albeit', 'hidden', 'secreci', 'magic', 'abil', 'inborn', 'children', 'abil', 'invit', 'attend', 'exclus', 'magic', 'school', 'teach', 'necessari', 'skill', 'succeed', 'wizard', 'world', 'harri', 'becom', 'student', 'hogwart', 'school', 'witchcraft', 'wizardri', 'wizard', 'academi', 'scotland', 'event', 'seri', 'take', 'place', 'harri', 'develop', 'adolesc', 'learn', 'overcom', 'problem', 'face', 'magic', 'social', 'emot', 'includ', 'ordinari', 'teenag', 'challeng', 'friendship', 'infatu', 'romant', 'relationship', 'schoolwork', 'exam', 'anxieti', 'depress', 'stress', 'greater', 'test', 'prepar', 'confront', 'lie', 'ahead', 'wizard', 'britain', 'second', 'wizard', 'war', 'novel', 'chronicl', 'one', 'year', 'harri', 'life', 'period', 'book', 'also', 'contain', 'mani', 'flashback', 'frequent', 'experienc', 'harri', 'view', 'memori', 'charact', 'devic', 'call', 'pensiev', 'environ', 'rowl', 'creat', 'intim', 'connect', 'realiti', 'british', 'magic', 'communiti', 'harri', 'potter', 'book', 'inspir', 'british', 'cultur', 'european', 'folklor', 'classic', 'mytholog', 'alchemi', 'incorpor', 'object', 'wildlif', 'magic', 'wand', 'magic', 'plant', 'potion', 'spell', 'fli', 'broomstick', 'centaur', 'magic', 'creatur', 'philosoph', 'stone', 'besid', 'other', 'invent', 'rowl', 'fantasi', 'land', 'narnia', 'altern', 'univers', 'lord', 'ring', 'mythic', 'past', 'wizard', 'world', 'harri', 'potter', 'exist', 'parallel', 'real', 'world', 'contain', 'magic', 'version', 'ordinari', 'element', 'everyday', 'life', 'action']

# %%
from collections import Counter 
Counter = Counter(stemmed)
most_occur = Counter.most_common(10) 
print(most_occur)
# Out:
# [('magic', 9), ('wizard', 8), ('harri', 7), ('world', 7), ('potter', 3), ('ordinari', 3), ('muggl', 3), ('charact', 2), ('seri', 2), ('live', 2)]

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
stopwords = set(STOPWORDS)

# %%
import sys
print(sys.executable)
# Out:
# /usr/bin/python3

# %%
def show_wordcloud(data, title = None):
    wordcloud = WordCloud(
        background_color='white',
        stopwords=stopwords,
        max_words=200,
        max_font_size=40, 
        scale=3,
        random_state=1 # chosen at random by flipping a coin; it was heads
    ).generate(str(data))

    fig = plt.figure(1, figsize=(12, 12))
    plt.axis('off')
    if title: 
        fig.suptitle(title, fontsize=20)
        fig.subplots_adjust(top=2.3)

    plt.imshow(wordcloud)
    plt.show()

# %%
show_wordcloud(stemmed)
